# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizNostradamus/Condicionais_2/blob/main/CONDICIONAIS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ARIVIDADE

# %%
### ATIVIDADE 01 ###
numero = float(input("Digite um numero: "))
if numero > 0:
  print("Numero positivo")
elif numero == 0:
  print("Numero nulo")
else:
  print("Numero negativo")
# Out:
# Digite um numero: -1
# Numero negativo

# %%
### ATIVIDADE 02 ###
numero = int(input("Digite um numero: "))
if numero %2 == 0:
  print("Numero par")
else:
  print("Numero impar")
# Out:
# Digite um numero: 11
# Numero impar

# %%
### ATIVIDADE 03 ###
nota = float(input("Digite sua nota: "))
if nota >= 7:
  print("Você foi aprovado")
elif nota >= 5:
  print("Você esta de recuperação")
else:
  print("Você foi reprovado")
# Out:
# Digite sua nota: 6.9
# Você esta de recuperação

# %%
### ATIVIDADE 04 ###
user = input("Digete seu usario: ")
senha = input("Digite sua senha: ")
if user == "admin" and senha == "1234":
  print("Login realizado com sucesso")
else:
  print("Login ou senha incorretos")
# Out:
# Digete seu usario: admin
# Digite sua senha: 111111
# Login ou senha incorretos
